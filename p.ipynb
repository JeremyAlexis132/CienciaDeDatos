# %%
ambiente = 'project'

# %%
data = spark.sql(
            f"""
                SELECT *
                FROM cor_{ambiente}.gold.wave_monthly_classification
                WHERE year = 2000
            """
        )

# %%
df = data.toPandas()

# %%
df.head(7)
# Out:
#    year month   coast_name wave_classification  percentage
# 0  2000    01  Salina Cruz         Mar agitado    8.600000
# 1  2000    12  Salina Cruz       Mar peligroso   54.169998
# 2  2000    05  Salina Cruz          Mar fuerte   18.280001
# 3  2000    09  Salina Cruz       Mar peligroso    9.030000
# 4  2000    08  Salina Cruz          Mar fuerte   23.250000
# 5  2000    06  Salina Cruz         Mar calmado    0.000000
# 6  2000    10  Salina Cruz        Mar dinámico    2.820000
